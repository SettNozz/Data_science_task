# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../data/shapes.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray_img, 100, 200)
plt.figure(figsize=(25,25))
plt.imshow(edges, cmap='gray')

# %%
lines[0]
# Out:
# array([[397.        ,   0.83775806]], dtype=float32)

# %%
import math as m

img = cv2.imread('../data/shapes.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray_img, 50, 150, apertureSize = 3)
lines = cv2.HoughLines(edges, 2, m.pi/180, 100)
for rho, tetha in lines[0]:
    a = m.cos(tetha)
    b = m.sin(tetha)
    x0 = a * rho
    y0 = b * rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)
plt.figure(figsize=(25,25))
plt.imshow(img)

# %%
img = cv2.imread('../data/shapes.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray_img, 100, 150, apertureSize = 3)
lines = cv2.HoughLinesP(edges, 1, m.pi/180, 100, 200, 10)
for x1,y1,x2,y2 in lines[0]:
    cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)
plt.figure(figsize=(25,25))
plt.imshow(img)

# %% [markdown]
# # Hough transform circles

# %%
img = cv2.imread('../data/shapes.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
circles = cv2.HoughCircles(gray_img, cv2.HOUGH_GRADIENT, 2, 80) # last arg: distance between center of circles 
print("Number of circles: {}".format(len(circles[0])))
# Out:
# Number of circles: 25

# %%
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(img,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(img,(i[0],i[1]),2,(0,0,255),3)
plt.figure(figsize=(30, 30))
plt.imshow(img)
